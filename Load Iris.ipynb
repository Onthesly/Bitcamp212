# %% [markdown]
# ## numpy 와 matplotlib 예시

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.random(10)*10

data2 = list(range(10))

plt.plot(data1, label='numpy')
plt.plot(data2, ':', label='list')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Iris 데이터 불러오기 (1)

# %%
import numpy as np

f = open('iris.csv')

line = f.readline()
features = line.strip().split(',')[:4]

data = []
for line in f:
    l = line.strip().split(',')
    l[0] = float(l[0])
    l[1] = float(l[1])
    l[2] = float(l[2])
    l[3] = float(l[3])
    
    if l[4] == 'Iris-setosa': l[4] = 0
    elif l[4] == 'Iris-versicolor': l[4] = 1
    else: l[4] = 2
        
    data.append(l)
    
f.close()

iris = np.array(data)
iris[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ]])

# %% [markdown]
# ## Iris 데이터 불러오기 (2)

# %%
import numpy as np

f = open('iris.csv')

line = f.readline()
features = line.strip().split(',')[:4]

labels = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

data = []
for line in f:
    l = line.strip().split(',')
    
    l[:4] = [float(i) for i in l[:4]]
    
    l[4] = labels.index(l[4])
        
    data.append(l)
    
f.close()

iris = np.array(data)
iris[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ]])

# %% [markdown]
# ## Iris 데이터 불러오기 (3)

# %%
import numpy as np

labels = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

iris = np.loadtxt('iris.csv', skiprows=1, delimiter=',', 
                 converters={4: lambda s: labels.index(s.decode())})
iris[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ]])

# %% [markdown]
# ## Iris 데이터 불러오기 (4)

# %%
import matplotlib.pyplot as plt

plt.plot(iris[:,:4])
plt.legend(features)

# %% [markdown]
# ## 속성별/클래스별 평균/표준편차/최대값/최소값

# %%
# 속성별/클래스별 평균
means = []
for i in np.unique(iris[:,4]):
    classes = iris[np.where(iris[:,4] == i)]
    means.append(np.mean(classes, axis=0))
np.array(means)
# Out:
# array([[5.006, 3.418, 1.464, 0.244, 0.   ],
#        [5.936, 2.77 , 4.26 , 1.326, 1.   ],
#        [6.588, 2.974, 5.552, 2.026, 2.   ]])

# %%
# 속성별/클래스별 표준편차
stds = []
for i in np.unique(iris[:,4]):
    classes = iris[np.where(iris[:,4] == i)]
    stds.append(np.std(classes[:,:4], axis=0))
np.array(stds)
# Out:
# array([[0.34894699, 0.37719491, 0.17176728, 0.10613199],
#        [0.51098337, 0.31064449, 0.46518813, 0.19576517],
#        [0.62948868, 0.31925538, 0.54634787, 0.27188968]])

# %%
# 속성별/클래스별 최대값
maxs = []
for i in np.unique(iris[:,4]):
    classes = iris[np.where(iris[:,4] == i)]
    maxs.append(np.max(classes, axis=0))
np.array(maxs)
# Out:
# array([[5.8, 4.4, 1.9, 0.6, 0. ],
#        [7. , 3.4, 5.1, 1.8, 1. ],
#        [7.9, 3.8, 6.9, 2.5, 2. ]])

# %%
# 속성별/클래스별 최소값
mins = []
for i in np.unique(iris[:,4]):
    classes = iris[np.where(iris[:,4] == i)]
    mins.append(np.min(classes, axis=0))
np.array(mins)
# Out:
# array([[4.3, 2.3, 1. , 0.1, 0. ],
#        [4.9, 2. , 3. , 1. , 1. ],
#        [4.9, 2.2, 4.5, 1.4, 2. ]])
